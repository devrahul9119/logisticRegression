# %%
import pandas as pd
import numpy as np 
from sklearn.datasets import make_classification 
from sklearn.metrics import r2_score
import plotly.express as px

# %%
X,y = make_classification(n_samples = 1000,n_features = 3,n_informative = 2,n_redundant = 0,n_classes = 3,n_clusters_per_class = 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
import matplotlib.pyplot as plt

# %%
fig = px.scatter_3d(X,X[:,0],X[:,1],X[:,2],color = y)
fig.update_layout(
    scene=dict(
        xaxis_title='X-Axis Label',
        yaxis_title='Y-Axis Label',
        zaxis_title='Z-Axis Label'
    ),
    title='3D Scatter Plot'
)
fig.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_
confusion_matrix(y_test,y_pred)
# Out:
# array([[72,  1,  3],
#        [ 2, 53,  2],
#        [ 8,  0, 59]], dtype=int64)
